# %%
from google.colab import drive
import sys
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
import re
import pandas as pd

# %%
structure_file = '/content/drive/My Drive/AbelBioToken-main/Proteomics/proteomexchange_datasets.json'

# Check if the file exists
if os.path.isfile(structure_file):
    print("File exists at the specified path.")
else:
    print("File does not exist at the specified path.")
# Out:
# File exists at the specified path.

# %%
# Open and load the JSON file
with open(structure_file, 'r') as file:
    data = json.load(file)

# %%
print(f"Type of data: {type(data)}")
# Out:
# Type of data: <class 'dict'>

# %%
if isinstance(data, dict):
    print("Top-level keys in the JSON data:")
    for key in data.keys():
        print(key)
# Out:
# Top-level keys in the JSON data:
# datasets
# facets
# query
# result_set
# status

# %%
from pprint import pprint

# Pretty-print the JSON data
pprint(data)
# Out:
# {'datasets': [['PXD036477',
#                'The human milk peptidome: exploring network insights',
#                'PRIDE',
#                'Homo sapiens',
#                'Q Exactive HF-X',
#                '<a href="https://dx.doi.org/10.1038/s41598-024-58127-2" '
#                'target="_blank">10.1038/s41598-024-58127-2</a>; <a '
#                'href="https://www.ncbi.nlm.nih.gov/pubmed/38555284" '
#                'target="_blank">Dekker et al. (2024)</a>',
#                'Sjef Boeren',
#                '2024-05-23',
#                'Breast milk, Homo sapiens, associations, network inference, '
#                'peptides, peptidomics'],
#               ['RPXD049956',
#                'Large-scale Discovery of Substrates of the Human Kinome (EGFR) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049955',
#                'Large-scale Discovery of Substrates of the Human Kinome (MST3) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049954',
#                'Large-scale Discovery of Substrates of the Human Kinome (p38g) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049953',
#                'Large-scale Discovery of Substrates of the Human Kinome (ITK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049952',
#                'Large-scale Discovery of Substrates of the Human Kinome (TAO1) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049951',
#                'Large-scale Discovery of Substrates of the Human Kinome (ROR2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049950',
#                'Large-scale Discovery of Substrates of the Human Kinome (LZK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049949',
#                'Large-scale Discovery of Substrates of the Human Kinome (SRM) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049948',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(DAPK1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049947',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PKCb2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049946',
#                'Large-scale Discovery of Substrates of the Human Kinome (PKCg) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049945',
#                'Large-scale Discovery of Substrates of the Human Kinome (CK1d) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049944',
#                'Large-scale Discovery of Substrates of the Human Kinome (TAO2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049943',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CDK2/CycA2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049942',
#                'Large-scale Discovery of Substrates of the Human Kinome (PKD3) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049941',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(ZAP70) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049940',
#                'Large-scale Discovery of Substrates of the Human Kinome (p38g) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049939',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CaMK1a) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049938',
#                'Large-scale Discovery of Substrates of the Human Kinome (MSK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049937',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(EPHA8) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049936',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CDC7/ASK) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049935',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(DYRK2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049934',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(EPHB2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049933',
#                'Large-scale Discovery of Substrates of the Human Kinome (WNK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049932',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CDK9/CycT1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049931',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(MAP2K4) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049930',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(ROCK1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049929',
#                'Large-scale Discovery of Substrates of the Human Kinome (RSK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049928',
#                'Large-scale Discovery of Substrates of the Human Kinome (TAO2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049927',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(HIPK2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049926',
#                'Large-scale Discovery of Substrates of the Human Kinome (PBK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049925',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CK2a1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049924',
#                'Large-scale Discovery of Substrates of the Human Kinome (MELK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049923',
#                'Large-scale Discovery of Substrates of the Human Kinome (MLK3) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049922',
#                'Large-scale Discovery of Substrates of the Human Kinome (PKN2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049921',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PFTAIRE1/cycD3) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049920',
#                'Large-scale Discovery of Substrates of the Human Kinome (TBK1) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049919',
#                'Large-scale Discovery of Substrates of the Human Kinome (BMX) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049918',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PKCb1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049917',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PDHK1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049916',
#                'Large-scale Discovery of Substrates of the Human Kinome (TTK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049915',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PKG1b) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049914',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(p70S6K) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049913',
#                'Large-scale Discovery of Substrates of the Human Kinome (ZAK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049912',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PIK3CB/PIK3R1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049911',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(AMPKa2/b1/g1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049910',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(GSK3a) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049909',
#                'Large-scale Discovery of Substrates of the Human Kinome (ROR1) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049908',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PDGFRA) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049907',
#                'Large-scale Discovery of Substrates of the Human Kinome (WNK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049906',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(DCLK2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049905',
#                'Large-scale Discovery of Substrates of the Human Kinome (EML4) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049904',
#                'Large-scale Discovery of Substrates of the Human Kinome (PKCd) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049903',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CaMK2d) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049902',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(AMPKa1/b1/g1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049901',
#                'Large-scale Discovery of Substrates of the Human Kinome (NIK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049900',
#                'Large-scale Discovery of Substrates of the Human Kinome (p38d) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049899',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CDK5/p25) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049898',
#                'Large-scale Discovery of Substrates of the Human Kinome (SGK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049897',
#                'Large-scale Discovery of Substrates of the Human Kinome (OSR1) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049896',
#                'Large-scale Discovery of Substrates of the Human Kinome (AXL) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049895',
#                'Large-scale Discovery of Substrates of the Human Kinome (ALK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049894',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CDK2/cycE1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049893',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(GPRK7) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049892',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CDK7/CycH/MAT1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049891',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(STLK3) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049890',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PDGFRa) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049889',
#                'Large-scale Discovery of Substrates of the Human Kinome (NEK6) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049888',
#                'Large-scale Discovery of Substrates of the Human Kinome (MYT1) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049887',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(ErbB2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049886',
#                'Large-scale Discovery of Substrates of the Human Kinome (TLK1) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049885',
#                'Large-scale Discovery of Substrates of the Human Kinome (WNK4) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049884',
#                'Large-scale Discovery of Substrates of the Human Kinome (YES) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049883',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(DYRK1A) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049882',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(SPHK1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049881',
#                'Large-scale Discovery of Substrates of the Human Kinome (BRK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049880',
#                'Large-scale Discovery of Substrates of the Human Kinome (CLK4) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049879',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(TESK1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049878',
#                'Large-scale Discovery of Substrates of the Human Kinome (TIE2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049877',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(ZAP70) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049876',
#                'Large-scale Discovery of Substrates of the Human Kinome (ICK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049875',
#                'Large-scale Discovery of Substrates of the Human Kinome (TLK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049874',
#                'Large-scale Discovery of Substrates of the Human Kinome (ABL2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049873',
#                'Large-scale Discovery of Substrates of the Human Kinome (PYK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049872',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(EphA7) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049871',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(LATS2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049870',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(MAPKAPK5) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049869',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PIP5K1C) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049868',
#                'Large-scale Discovery of Substrates of the Human Kinome (CLK3) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049867',
#                'Large-scale Discovery of Substrates of the Human Kinome (CK1e) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049866',
#                'Large-scale Discovery of Substrates of the Human Kinome (EGFR) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049865',
#                'Large-scale Discovery of Substrates of the Human Kinome (NEK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049864',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PDGFRb) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049863',
#                'Large-scale Discovery of Substrates of the Human Kinome (QIK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049862',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(STK33) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049861',
#                'Large-scale Discovery of Substrates of the Human Kinome (JAK2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049860',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CK1g2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049859',
#                'Large-scale Discovery of Substrates of the Human Kinome (FLT4) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049858',
#                'Large-scale Discovery of Substrates of the Human Kinome (CHK1) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049857',
#                'Large-scale Discovery of Substrates of the Human Kinome (ROS) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049856',
#                'Large-scale Discovery of Substrates of the Human Kinome (PKD3) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049855',
#                'Large-scale Discovery of Substrates of the Human Kinome (PKD2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049854',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PDHK4) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049853',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CAMKK2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049852',
#                'Large-scale Discovery of Substrates of the Human Kinome (ALK) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049851',
#                'Large-scale Discovery of Substrates of the Human Kinome (DDR2) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049850',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(PKCb2) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049849',
#                'Large-scale Discovery of Substrates of the Human Kinome (MET) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049848',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(EPHA6) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049847',
#                'Large-scale Discovery of Substrates of the Human Kinome (p38a) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049846',
#                'Large-scale Discovery of Substrates of the Human Kinome (MSK1) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049845',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(MAPKAPK3) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049844',
#                'Large-scale Discovery of Substrates of the Human Kinome (AurC) '
#                '[Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049843',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(TYRO3) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049842',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(DMPK1) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                'no publication',
#                'Yasushi Ishihama',
#                '2024-02-21',
#                'HeLa, Homo sapiens, in vitro kinase assay, reanalysis'],
#               ['RPXD049841',
#                'Large-scale Discovery of Substrates of the Human Kinome '
#                '(CDK4/CycD3) [Reanalysis: JPST000508]',
#                'jPOST',
#                'Homo sapiens',
# ...
#                '<a href="https://www.ncbi.nlm.nih.gov/pubmed/36762613" '
#                'target="_blank">Ozkan et al. (2023)</a>',
#                'Nurhan Ozlu',
#                '2023-02-27',
#                'BioID, HeLa, Homo sapiens, PCDH7, cell cycle, mitosis, '
#                'protocadherin'],
#               ['PXD034806',
#                'The human milk proteome: exploring associations with allergy '
#                'of mother and child',
#                'PRIDE',
#                'Homo sapiens',
#                'Q Exactive HF-X',
#                'Dataset with its publication pending',
#                'Sjef Boeren',
#                '2022-10-31',
#                'Breast milk, Homo sapiens, allergic disease, allergy, '
#                'immunology, proteins'],
#               ['PXD011366',
#                'Large-scale Discovery of Substrates of the Human Kinome',
#                'jPOST',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/31324866" '
#                'target="_blank">Sugiyama, Imamura & Ishihama (2019)</a>',
#                'Yasushi Ishihama',
#                '2022-09-18',
#                'HeLa, Homo sapiens, in vitro kinase assay'],
#               ['PXD032925',
#                'Distinct roles of the two Elongator subcomplexes during '
#                'neurodevelopment',
#                'PRIDE',
#                'Homo sapiens',
#                'TripleTOF 5600',
#                'Dataset with its publication pending',
#                'Brandon Wainwright',
#                '2022-05-17',
#                'Fibroblasts, Homo sapiens, Intellectual disability, '
#                'developmental delay, epilepsy'],
#               ['PXD028280',
#                'Human milk dynamics: Inter-individual variation in milk '
#                'proteome',
#                'PRIDE',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/35104145" '
#                'target="_blank">Dekker et al. (2022)</a>',
#                'Sjef Boeren',
#                '2022-05-04',
#                'Breast milk, Homo sapiens, proteins, variability'],
#               ['PXD028294',
#                'Human milk dynamics: Inter-individual variation in peptidome',
#                'PRIDE',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/35104145" '
#                'target="_blank">Dekker et al. (2022)</a>',
#                'Sjef Boeren',
#                '2022-05-04',
#                'Breast milk, Homo sapiens, peptides, peptidomics, variability'],
#               ['PXD025223',
#                'Comparative proteomic and metabolomic analysis of human '
#                'osteoblasts differentiated from dental pulp stem cells',
#                'PRIDE',
#                'Homo sapiens',
#                'SYNAPT G2-Si',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/34360674" '
#                'target="_blank">NovÃ¡kovÃ¡ et al. (2021)</a>',
#                'Andrej KovÃ¡Ä\x8d',
#                '2021-11-03',
#                'Homo sapiens, NMR, bone metabolism, label-free quantification, '
#                'late osteoblast, mineralization phase, osteodifferentiation, '
#                'signaling pathways'],
#               ['PXD015871',
#                'Potential interactors of alpha-tubulin acetyltransferase 1 '
#                '(Î±TAT1/MEC17)',
#                'PRIDE',
#                'Homo sapiens',
#                'Orbitrap Fusion',
#                'Dataset with its publication pending',
#                'Damarys Loew',
#                '2021-11-02',
#                'HEK cells, Homo sapiens, MEC17, Î±TAT1'],
#               ['PXD024194',
#                'Identification of TI-4-interacting proteins',
#                'PRIDE',
#                'Homo sapiens',
#                'maXis',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/34022224" '
#                'target="_blank">Nagashima et al. (2021)</a>',
#                'Yutaka HATA',
#                '2021-09-10',
#                'Homo sapiens, TAZ, TI-4'],
#               ['PXD026520',
#                '8OHdG receptors on the cell surface of CCDC25 overexpressed '
#                'HEK293T cells identified by SPIDER assay',
#                'iProX',
#                'Homo sapiens',
#                'Q Exactive Plus',
#                'Dataset with its publication pending',
#                'Shengce Tao',
#                '2021-06-06',
#                'CCDC25, Homo sapiens, pupylation'],
#               ['PXD026517',
#                'Pupylation sites on protein Sox2',
#                'iProX',
#                'Homo sapiens',
#                'Q Exactive Plus',
#                '<a href="https://www.ncbi.nlm.nih.gov/pubmed/37059927" '
#                'target="_blank">Jiang et al. (2023)</a>',
#                'Shengce Tao',
#                '2021-06-06',
#                'Homo sapiens, Sox2, pupylation'],
#               ['PXD026511',
#                'Pupylation sites on protein FKBP12',
#                'iProX',
#                'Homo sapiens',
#                'Q Exactive Plus',
#                'Dataset with its publication pending',
#                'Shengce Tao',
#                '2021-06-06',
#                'FKBP12, Homo sapiens'],
#               ['PXD022987',
#                'The Ubiquitin-Specific Protease USP36 Promotes Small Nucleolar '
#                'Ribonucleoprotein Group SUMOylation and is Essential for '
#                'Ribosome Biogenesis',
#                'PRIDE',
#                'Homo sapiens',
#                'LTQ',
#                'Dataset with its publication pending',
#                'Mu-Shui Dai',
#                '2021-03-29',
#                'Co-IP, Deubiquitinating enzyme, Homo sapiens, LTQ Velos, '
#                'Ribosome biogenesis, SUMO, SUMOylation, Spectral Count, USP36, '
#                'nucleolus'],
#               ['PXD020113',
#                'Parthenolide-treated HeLa cells and purified tubulin',
#                'PRIDE',
#                'Homo sapiens',
#                'Q Exactive',
#                'Dataset with its publication pending',
#                'Alexey I. Nesvizhskii',
#                '2021-03-04',
#                'Homo sapiens, Q Exactive, parthenolide, tubulin'],
#               ['PXD015233',
#                'Lysine fatty-acyl H3 peptide pulldown with HeLa SILAC nuclear '
#                'extract',
#                'PRIDE',
#                'Homo sapiens',
#                'LTQ Orbitrap Elite',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/31578417" '
#                'target="_blank">0</a>',
#                'Katrin Chua',
#                '2019-10-02',
#                'Homo sapiens, Orbitrap Elite'],
#               ['PXD015272',
#                'Fatty-acyl conjugated amino-hexyl agarose pulldown with HeLa '
#                'SILAC whole cell extract',
#                'PRIDE',
#                'Homo sapiens',
#                'Orbitrap Fusion Lumos',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/31578417" '
#                'target="_blank">Li et al. (2019)</a>',
#                'Katrin Chua',
#                '2019-10-02',
#                'Homo sapiens, Orbitrap Fusion Lumos'],
#               ['PXD003459',
#                'The interactome of the human RNA Pol II',
#                'PRIDE',
#                'Homo sapiens',
#                'LTQ Orbitrap',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/27264542" '
#                'target="_blank">Hintermair et al. (2016)</a>',
#                'Axel Imhof',
#                '2018-01-09',
#                'Homo sapiens, Interactome, RNA Pol II'],
#               ['PXD007591',
#                'Proteomic characterization of human exhaled breath condensate',
#                'PRIDE',
#                'Homo sapiens',
#                'LTQ Orbitrap Velos',
#                '<a href="http://www.ncbi.nlm.nih.gov/pubmed/29189203" '
#                'target="_blank">Lacombe et al. (2017)</a>',
#                'Virginie Brun',
#                '2017-12-06',
#                'Homo sapiens, exhaled breath condensate, nanoLC-MS/MS'],
#               ['PXD002228',
#                'Mammalian Bcnt/Cfdp1, a potential epigenetic factor '
#                'characterized by an acidic stretch in the disordered '
#                'N-terminal and S250 phosphorylation in the conserved '
#                'C-terminal regions',
#                'PRIDE',
#                'Homo sapiens',
#                'Q Exactive',
#                'Dataset with its publication pending',
#                'Takehiro Suzuki',
#                '2015-06-25',
#                'Homo sapiens, Q Exactive']],
#  'facets': {'instrument': [{'count': 431, 'name': 'LTQ Orbitrap'},
#                            {'count': 3, 'name': 'Orbitrap Exploris 480'},
#                            {'count': 3, 'name': 'Q Exactive'},
#                            {'count': 3, 'name': 'Q Exactive Plus'},
#                            {'count': 2, 'name': 'Q Exactive HF-X'},
#                            {'count': 2, 'name': 'TripleTOF 5600'},
#                            {'count': 1, 'name': 'SYNAPT G2-Si'},
#                            {'count': 1, 'name': 'Orbitrap Fusion'},
#                            {'count': 1, 'name': 'maXis'},
#                            {'count': 1, 'name': 'LTQ'},
#                            {'count': 1, 'name': 'LTQ Orbitrap Elite'},
#                            {'count': 1, 'name': 'Orbitrap Fusion Lumos'},
#                            {'count': 1, 'name': 'LTQ Orbitrap Velos'}],
#             'keywords': [{'count': 451, 'name': 'Homo sapiens'},
#                          {'count': 428, 'name': 'HeLa'},
#                          {'count': 427, 'name': 'in vitro kinase assay'},
#                          {'count': 426, 'name': 'reanalysis'},
#                          {'count': 4, 'name': 'Breast milk'},
#                          {'count': 2, 'name': 'peptides'},
#                          {'count': 2, 'name': 'peptidomics'},
#                          {'count': 2, 'name': 'Metaproteomics'},
#                          {'count': 2, 'name': 'Paeoproteomics'},
#                          {'count': 2, 'name': 'Teeth'},
#                          {'count': 2, 'name': 'proteins'},
#                          {'count': 2, 'name': 'variability'},
#                          {'count': 2, 'name': 'pupylation'},
#                          {'count': 2, 'name': 'Q Exactive'},
#                          {'count': 1, 'name': 'associations'},
#                          {'count': 1, 'name': 'network inference'},
#                          {'count': 1, 'name': 'Ilsenhöhle Ranis'},
#                          {'count': 1, 'name': 'LRJ'},
#                          {'count': 1, 'name': 'Species identification'},
#                          {'count': 1, 'name': 'mass-spectrometry'},
#                          {'count': 1, 'name': 'palaeoproteomics'},
#                          {'count': 1, 'name': 'HbA1c'},
#                          {'count': 1, 'name': 'glycation'},
#                          {'count': 1, 'name': 'human serum albumin'},
#                          {'count': 1, 'name': 'kidney'},
#                          {'count': 1, 'name': 'microalbuminuria'},
#                          {'count': 1, 'name': 'plasma'},
#                          {'count': 1, 'name': 'BioID'},
#                          {'count': 1, 'name': 'PCDH7'},
#                          {'count': 1, 'name': 'cell cycle'},
#                          {'count': 1, 'name': 'mitosis'},
#                          {'count': 1, 'name': 'protocadherin'},
#                          {'count': 1, 'name': 'allergic disease'},
#                          {'count': 1, 'name': 'allergy'},
#                          {'count': 1, 'name': 'immunology'},
#                          {'count': 1, 'name': 'Fibroblasts'},
#                          {'count': 1, 'name': 'Intellectual disability'},
#                          {'count': 1, 'name': 'developmental delay'},
#                          {'count': 1, 'name': 'epilepsy'},
#                          {'count': 1, 'name': 'NMR'},
#                          {'count': 1, 'name': 'bone metabolism'},
#                          {'count': 1, 'name': 'label-free quantification'},
#                          {'count': 1, 'name': 'late osteoblast'},
#                          {'count': 1, 'name': 'mineralization phase'},
#                          {'count': 1, 'name': 'osteodifferentiation'},
#                          {'count': 1, 'name': 'signaling pathways'},
#                          {'count': 1, 'name': 'HEK cells'},
#                          {'count': 1, 'name': 'MEC17'},
#                          {'count': 1, 'name': 'Î±TAT1'},
#                          {'count': 1, 'name': 'TAZ'},
#                          {'count': 1, 'name': 'TI-4'},
#                          {'count': 1, 'name': 'CCDC25'},
#                          {'count': 1, 'name': 'Sox2'},
#                          {'count': 1, 'name': 'FKBP12'},
#                          {'count': 1, 'name': 'Co-IP'},
#                          {'count': 1, 'name': 'Deubiquitinating enzyme'},
#                          {'count': 1, 'name': 'LTQ Velos'},
#                          {'count': 1, 'name': 'Ribosome biogenesis'},
#                          {'count': 1, 'name': 'SUMO'},
#                          {'count': 1, 'name': 'SUMOylation'},
#                          {'count': 1, 'name': 'Spectral Count'},
#                          {'count': 1, 'name': 'USP36'},
#                          {'count': 1, 'name': 'nucleolus'},
#                          {'count': 1, 'name': 'parthenolide'},
#                          {'count': 1, 'name': 'tubulin'},
#                          {'count': 1, 'name': 'Orbitrap Elite'},
#                          {'count': 1, 'name': 'Orbitrap Fusion Lumos'},
#                          {'count': 1, 'name': 'Interactome'},
#                          {'count': 1, 'name': 'RNA Pol II'},
#                          {'count': 1, 'name': 'exhaled breath condensate'},
#                          {'count': 1, 'name': 'nanoLC-MS/MS'}],
#             'repository': [{'count': 427, 'name': 'jPOST'},
#                            {'count': 21, 'name': 'PRIDE'},
#                            {'count': 3, 'name': 'iProX'}],
#             'species': [{'count': 451, 'name': 'Homo sapiens'},
#                         {'count': 2, 'name': 'Archaea'},
#                         {'count': 2, 'name': 'Eukaryota'},
#                         {'count': 2, 'name': 'Viruses'},
#                         {'count': 1, 'name': 'Bacteria'}],
#             'year': [{'count': 427, 'name': '2024'},
#                      {'count': 6, 'name': '2023'},
#                      {'count': 5, 'name': '2022'},
#                      {'count': 8, 'name': '2021'},
#                      {'count': 2, 'name': '2019'},
#                      {'count': 1, 'name': '2018'},
#                      {'count': 1, 'name': '2017'},
#                      {'count': 1, 'name': '2015'}]},
#  'query': {'accession': None,
#            'contact': None,
#            'instrument': None,
#            'keywords': 'Homo sapiens',
#            'modification': None,
#            'pageNumber': 1,
#            'pageSize': 1000000,
#            'publication': None,
#            'repository': None,
#            'resultType': 'compact',
#            'search': None,
#            'species': 'Homo sapiens',
#            'year': None},
#  'result_set': {'datasets_title_list': ['dataset identifier',
#                                         'title',
#                                         'repository',
#                                         'species',
#                                         'instrument',
#                                         'publication',
#                                         'lab head',
#                                         'announce date',
#                                         'keywords'],
#                 'n_available_pages': 1,
#                 'n_available_rows': 451,
#                 'n_rows_returned': 451,
#                 'page_number': 1,
#                 'page_size': 1000000},
#  'status': {'description': 'Sent 451 datasets',
#             'error_code': None,
#             'status': 'OK',
#             'status_code': 200}}

# %%
# Function to convert datasets to list of dictionaries
def get_datasets_as_dicts(data):
    datasets = data['datasets']
    field_names = data['result_set']['datasets_title_list']
    datasets_dicts = []

    for dataset in datasets:
        dataset_dict = dict(zip(field_names, dataset))
        datasets_dicts.append(dataset_dict)

    return datasets_dicts

# Load datasets as dictionaries
datasets = get_datasets_as_dicts(data)

# Function to strip HTML tags
def strip_html_tags(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# Clean the 'publication' field
for dataset in datasets:
    if 'publication' in dataset:
        dataset['publication'] = strip_html_tags(dataset['publication'])

# Function to print dataset details
def print_dataset_details(dataset):
    for key, value in dataset.items():
        print(f"{key}: {value}")
    print("\n" + "-"*50 + "\n")

# Example: Print the first dataset
print("First dataset after cleaning 'publication' field:")
print_dataset_details(datasets[0])

# Convert to DataFrame
df = pd.DataFrame(datasets)
print("Datasets DataFrame:")
print(df.head())

# Save DataFrame to CSV
output_file = '/content/drive/My Drive/AbelBioToken-main/Proteomics/proteomexchange_datasets.csv'
df.to_csv(output_file, index=False)
print(f"DataFrame saved to {output_file}")
# Out:
# First dataset after cleaning 'publication' field:
# dataset identifier: PXD036477
# title: The human milk peptidome: exploring network insights
# repository: PRIDE
# species: Homo sapiens
# instrument: Q Exactive HF-X
# publication: 10.1038/s41598-024-58127-2; Dekker et al. (2024)
# lab head: Sjef Boeren
# announce date: 2024-05-23
# keywords: Breast milk, Homo sapiens, associations, network inference, peptides, peptidomics
#
# --------------------------------------------------
#
# Datasets DataFrame:
#   dataset identifier                                              title  \
# 0          PXD036477  The human milk peptidome: exploring network in...
# 1         RPXD049956  Large-scale Discovery of Substrates of the Hum...
# 2         RPXD049955  Large-scale Discovery of Substrates of the Hum...
# 3         RPXD049954  Large-scale Discovery of Substrates of the Hum...
# 4         RPXD049953  Large-scale Discovery of Substrates of the Hum...
#
#   repository       species       instrument  \
# 0      PRIDE  Homo sapiens  Q Exactive HF-X
# 1      jPOST  Homo sapiens     LTQ Orbitrap
# 2      jPOST  Homo sapiens     LTQ Orbitrap
# 3      jPOST  Homo sapiens     LTQ Orbitrap
# 4      jPOST  Homo sapiens     LTQ Orbitrap
#
#                                         publication          lab head  \
# 0  10.1038/s41598-024-58127-2; Dekker et al. (2024)       Sjef Boeren
# 1                                    no publication  Yasushi Ishihama
# 2                                    no publication  Yasushi Ishihama
# 3                                    no publication  Yasushi Ishihama
# 4                                    no publication  Yasushi Ishihama
#
#   announce date                                           keywords
# 0    2024-05-23  Breast milk, Homo sapiens, associations, netwo...
# 1    2024-02-21  HeLa, Homo sapiens, in vitro kinase assay, rea...
# 2    2024-02-21  HeLa, Homo sapiens, in vitro kinase assay, rea...
# 3    2024-02-21  HeLa, Homo sapiens, in vitro kinase assay, rea...
# 4    2024-02-21  HeLa, Homo sapiens, in vitro kinase assay, rea...
# DataFrame saved to /content/drive/My Drive/AbelBioToken-main/Proteomics/proteomexchange_datasets.csv

# %%
facets = data['facets']

# Print available facets
print("Available facets:")
for facet_name in facets.keys():
    print(facet_name)
# Out:
# Available facets:
# instrument
# keywords
# repository
# species
# year
